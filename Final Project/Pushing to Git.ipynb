# %%
# !apt-get update
# !apt-get install git-lfs

# Defined name of variables for repos and also for access
repository_url = "https://github.com/adityaladhani/DSIF_Capstone.git"
repository_name = "DSIF_Capstone"
folder_to_upload = "/content/drive/MyDrive/Data Science in Finance/python-material/Final Project"
github_username = "adityaladhani"
github_pat = "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"

# !git clone "$repository_url"

# **Important: Correct the cd command**
# !cd "$repository_name"  # Use quotes to handle spaces in folder names

# !git lfs install

# Ensuring the right directory has been mapped to
import os

print(f"Current working directory: {os.getcwd()}")  # Add this line

# Navigate to the repository directory
os.chdir(repository_name)

# Defining the destination for the folder to be uploaded to
import shutil

destination_folder = os.path.join(os.getcwd(), "Final Project")  # Name the folder inside the repo
shutil.copytree(folder_to_upload, destination_folder)

# **LFS Tracking: Add this before adding files!**
# !git lfs track "*.csv"  # Track CSV files (adjust as needed)
# !git add .gitattributes # **Crucially, add the .gitattributes file**

# Add the folder to the Git staging area
# !git add "Final Project"

# Configure Git user info
# !git config --global user.email "aditya.ladhani@gmail.com"
# !git config --global user.name "Adi Ladhani"

# Commit the changes
# !git commit -m "Add final project with LFS tracking"  # Be specific in the commit message

# Push the commit using credentials
remote_url = f"https://{github_username}:{github_pat}@github.com/{github_username}/{repository_name}.git"
# !git push "$remote_url" main

print("Attempt to push completed (check for errors).")
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# ...
